# %%
import pandas as pd
import transformers
from transformers import GPT2Tokenizer, GPT2ForSequenceClassification
import torch
from torch.utils.data import Dataset, DataLoader

# %%
df = pd.read_csv("CSN.csv")

df_seek = df.copy()
df_seek.loc[df_seek['label'] == 2, 'label'] = 0
df_seek['label'].value_counts()
df_seek
# Out:
#                                                    text  label
# 0                 I don't know who left other than him.      0
# 1     I also was very depressed and cryed very very ...      1
# 2     I am a 6 yr survivor and have been out of trea...      0
# 3             I have enough energy for 16 hour periods.      0
# 4            I was diagnosed in October 2009 at age 53.      0
# ...                                                 ...    ...
# 5002  You are a creative person, and I can just imag...      0
# 5003  I thought they were supposed to eliminate the ...      0
# 5004  I could use a good hug too, from someone who u...      1
# 5005  You take 1 pill one hour prior to treatment, 1...      0
# 5006    Please anything will help me get through this..      1
#
# [5007 rows x 2 columns]

# %% [markdown]
# Here is an example code for training a text classification dataset using GPT-3 with the Hugging Face Transformers library:
#
# In this example, a custom TextClassificationDataset is defined to hold the training data and labels. The dataset is then passed to a PyTorch DataLoader for batch processing during training. The GPT2ForSequenceClassification model is loaded from a pre-trained checkpoint, and set to train mode using the train method. The cross entropy loss function and Adam optimizer are defined for training, and the model is trained using a loop over the training data. The loop updates the model parameters using the step method of the optimizer, and the loss is printed after each epoch.
#
# You can modify this code to use your own dataset by replacing the data and labels arrays with your own data and labels, and adjusting the training loop and loss function as needed for your specific task.

# %%
# Load the training data
# data = [["This is a positive text"], ["This is a negative text"]]
# labels = [1, 0]

data = []
for i in df_seek['text']:
    data.append([i])
labels = df_seek['label'].to_list()
data
# Out:
# [["I don't know who left other than him."],
#  ['I also was very depressed and cryed very very much even tho I had a good prognosis considering.'],
#  ['I am a 6 yr survivor and have been out of treatment for 5 yrs.'],
#  ['I have enough energy for 16 hour periods.'],
#  ['I was diagnosed in October 2009 at age 53.'],
#  ['But at 7 pm tonight his left ankle started swelling.'],
#  ['I just wanted to let you know I was here if you wanted to talk.'],
#  ["I see him week after next so we'll see what he days, actually I don't think one can have the shot while on chemo, thoughts anyone?"],
#  ['I had non-small cell lung cancer, adenocarcinoma, which was a slow moving cancer.'],
#  ["I was lucky and didn't feel much pain, but those darn drains are a pain in the butt."],
#  ['I thought I was dying  I could not think straight, I was weak and nauseous.'],
#  ['I believe, correct me if I am wrong, that doing it yourself gives you at least a little control.'],
#  ['Your attitude is amazing and, for me, very contagious, you are brave.'],
#  ['And, I as others here, like the window view.'],
#  ['But sure enough, the day came when my husband wanted to stop hearing the "C" word and wanted me to move on.'],
#  ['She forgot she smoked most of the time.'],
#  ['After an hour or so, does the breathing issue subside?'],
#  ['It must be awful to be so far away, I feel for you hope hope!'],
#  ['It is just too hard to find out if you have lung cancer often until it is too late.'],
#  ['You may wish to have a doctor take a biopsy from a bronchoscopy, if the nodule is accessible via that non-invasive procedure.'],
#  ['My problem is that I get tired so easily.'],
#  ['CT in July 2013 showed the largest node in the left lung has grown.'],
#  ['I completed rad/chemo in 2004 and have COPD so I can expect fluid buildup every 3 to 6 months.'],
#  ['When they did a PET Scan they found a mass on his lung too.'],
#  ['I couldnt find much info when I googled it.'],
#  ['Was glad to find this site and great info being shared.'],
#  ["Please  pm me I'd love to find you on facebook"],
#  ['I am so glad you are able to start fighting the cancer again, and keep it depleted and disappearing forever.'],
#  ['I was very happy my eyebrows grew in althou they are thin and not like before.'],
#  ['You have beaten your cancer, put the issue of it back where it belongs, and live your life....'],
#  ['I had a bumpy rash for a short while towards the end of rads.'],
#  ['I used Aquafor skin lotion/gel  (over the counter) for  radiation side effects on my skin.'],
#  ['Pain in my legs and all muscles was unbearable.'],
#  ['If you would like to talk on the phone email me your number and I would be happy to call you.'],
#  ['She has heard about all the women who have lost the battle, believe me, that scares the S#@t out of her.'],
#  ['Doctors need to write things a certain way to force insurance companies to pay up.'],
#  ['No two people are alike and we all handle and heal differently.'],
#  ['They usually will tap this fluid to test the cells to determine if they are malignant or not.'],
#  ['I had invasive Ductal carcinoma with metaplastic differentiation.'],
#  [" Judy, I was started on Femara in January of 2011 untill I was switched over(can't remember when I switched)to the generic form,Letrozole."],
#  ['Many of us here were diagnosed before age of 50,'],
#  ['I was diagnosed about 3 weeks ago and had surgery last week, I still think about it A LOT.'],
#  ["i know black pepper is not hot compared to other peppers but it's still too hot for me."],
#  ['I am sad for your cousin, still in disbelief that anyone these days can actually LOSE the fight to breast cancer!!!!!'],
#  ['It was a real surgery, and now I have this thing in my throat, chest.'],
#  ["Fortunately she's a nurse and understood that it was the meds and not something personal or anything permanent."],
#  ['I have good range of motion in both arms.'],
#  ['Im heart broke watching my husband and his gamily go three this again.'],
#  ['I have pain in my rib area on the left side now.'],
#  ['My chest is still tight at times and my ribs are still tender if I press on them.'],
#  ['I had my left breast removed last May.'],
#  ['This helped immensley with the pain I was experiencing and now no longer need pain meds, I start high dose chemo next week.'],
#  ['They did ask if I worked around kids.'],
#  ['I did remain overnight and expected to stay another day.'],
#  ['All her suggestions will make your life a whole lot easier.'],
#  ['It seems like such a very very BAD Dream.'],
#  ["He is mobile & insists on going to the store, etc, so I don't think that is a viable option, at this time."],
#  ["It is almost 4 weeks since I finished chemo and don't see much growth of any hair."],
#  ['Maybe her mouth runs faster than her brain.'],
#  ['I am at a loss where to go on the internet for help and understanding.'],
#  ["Some patients experience similar symptoms like being tired, sick, losing hair, eyelashes (no less as if drawing eyebrows isn't bad enough!"],
#  ['I had papillary thyroid cancer 3 years ago and the tumors did not show up on my annual whole body scan.'],
#  ['Inability to draw a deep breath often causes anxiety, which, in turn, makes the inherent depression and frustration worse.'],
#  ['Very sorry to read about your sister but so happy that she is going to be alright now.'],
#  ['Am stage 11B, upper left lobe removed 12-4-01, one positive lymph node (although it was not mediastinal).'],
#  ['I also was horribly upset about losing my hair.'],
#  ['Anyone have experience with being too weak to walk?'],
#  ['Only between 1% and 5% of all BC is IBC so many do not know how different it is than the other types.'],
#  ['Take your weary days and rest and find sources of strength and joy wherever that may be.'],
#  ['Your response is what it is, just what you are feeling at this point in your treatment.'],
#  ['I respect your decision to refuse treatment, I am sure Stayingcalm does also along with many others on this site.'],
#  ['Had biopsies done on thursday waiting for results.'],
#  ['ANd pass the chocolate and latest issue of Country Living.'],
#  ['I hate that I had to go through treatments twice too!'],
#  ['Just the word radiation frightens me, I am so scared for her.'],
#  ['During the healing process you need to eat a well balanced diet.'],
#  ['I received carboplatin and taxol for 8 months till tumors started to grow.'],
#  ['You enjoy your very well deserved and very long dance with NED!'],
#  ['I started my chemo on Feb. 1st, so it took a couple of months to set in.'],
#  ['And even if it is cancer, it can be treated.'],
#  ['Said all they do are drive women nuts.'],
#  ["To bring someone else's anything into the room were you are is very unprofessional."],
#  ["His partner said a bridge and one implant on the bottom (where I haven't had a tooth for years) wound be sufficient."],
#  ['Experiment until you find what is best for you.'],
#  ['Yesterday I went to the doctor and they told me that they found lumps under my bra line and one in my stomach.'],
#  ['Thank you again for representing all of us in such an important, inspirational way!'],
#  ['Comes in a bag that has 12 individual snacks inside.'],
#  ['..and I have just lost my eyebrows too.'],
#  ['Most insurance pays for a few counseling sessions a year, mine does.'],
#  ['Thank you and God Bless for your help!'],
#  ['Falling or having a knee give out can be very unnerving.'],
#  ['The 2nd infusion had to be stopped about 7 minutes into the infusion because I had a terrible allergic reaction.'],
#  ['Radiation and tamoxifen will be all she needs.'],
#  ['Thanks again for your warm wishes and welomes.'],
#  ['Remember that they are cutting through muscle and possibly tendons.'],
#  ['Bringing cafe au lait and beignets and big hugs.'],
#  ["I am now a Medical Assistant and I work in a Doctor's office."],
#  ['I hope this helps and again would be glad to talk .'],
#  ["I'm glad I have you guys that support us."],
#  ['Also please know that 90-95% of lung nodules resolve themselves.'],
#  ['Has anyone had this pain and do they know how to get rid of it?'],
#  [': )    I am also about 3 weeks after a lumpectomy and lymph node removal.'],
#  ['I too felt a bit of a bond after reading your posts and listening to the radio broadcast.'],
#  ['Also post your question on inspire.com'],
#  ['My thoughts and prayers are with all the families.'],
#  ['In May 2001, at age 67, I was initially diagnosed inoperable/incurable.'],
#  ['My mom has squamous cell cancer type 3.'],
#  ["Please don't apologize for they way you feel."],
#  ['Had 1st chemo yesterday and having the port was great.'],
#  ['My husband started on alinita, Avastin and Paraplatin on the 21 day cycle about two weeks ago.'],
#  ['Is losing hair a sign that is works?'],
#  ['I understood where they were coming from, but it was so very hard.'],
#  ['I have 3b nsclc and went through carbo/taxol 1 per week for 22 weeks.'],
#  ['Go to Inspire.com and post your questions'],
#  ['Stay warm & cozy now, you deserve a rest, I undersnad how it should feel!'],
#  ['How were you diagnosed and what were your symptoms?'],
#  ['He has since left due to the commute.'],
#  ['Thanks for the update was hoping he was home by now my thoughts and prayers are still with you.'],
#  ['RE, I think your comments are very caring indeed.'],
#  ['How long will your ports be left in?'],
#  ['I love to hear survial stories like yours and thank you for the encouragement.'],
#  ['This works much the same as chewing ice when getting chemo to prevent mouth sores (mucositis).'],
#  ['There are always trial drugs and something to try.'],
#  ['Such nice comments from such a wonderful lady!'],
#  ['I also had a breast reduction on my left (non-cancer) side.'],
#  ['Not very hungry, but I do try to keep drinking water or some other type of fluid.'],
#  ['My lung infections cleared right up after the cancer was removed.'],
#  ['I was diagnosed with grade 3 invasive ductal carcinoma, stage 3b with at least one lymph node involved.'],
#  ['This is in reply to boating, my husband was diagnosed with SCLC last November, was in remission for 6 weeks.'],
#  ['And there may some that left and have returned or some that left here completely.'],
#  ['How very strong your friend must have been to endure all that in one month.'],
#  ['my oncologist and my surgeon both recommended gall bladder out before cancer.'],
#  ['I did reply to your other post on mouth sores.'],
#  ['He believes that chemotherapy is the best treatment for her and wants her to start by next week.'],
#  ['I recommend to everyone that they get a prosthesis bra and form where they can get a fitting at the same time.'],
#  ["I'm not stressing about it because by then, there will probably be new guidelines."],
#  ['I went through all the treatment, but I no longer know why I went to all the trouble.'],
#  ['It felt like the Taxol was killing me.'],
#  ['I was overwhelmed how much support I got from friends and family.'],
#  ['I loved my curly hair that lasted a year.'],
#  ['She also takes her regular pain meds, but they constipated.'],
#  ['This monday is the last, I hope that he regains his mobility.'],
#  ['Check out the following forum entry (in Head/Neck Cancer forum) where there has apparently been vigorous discussion about the CTCA:'],
#  ['SO ANY INFO WOULD BE MOST APPRECIATED, THANKS IN ADVANCE'],
#  ['Instead you strike up an odd and sustaining friendship.'],
#  ['It is in the clear area between my lung and sternum (3 cm tumor).'],
#  ['I looked over at my co-worker and she had a weird look on her face!'],
#  ['after every chemo treatment I had to take a shot called Neulasta.'],
#  ['Remember to take good care of yourself and have a Happy New Year!'],
#  ["Miracles do happen, some of us get it and some don't, but life itself is a miracle right?"],
#  ['www.cancersurvivor.com is a great site site for chatters.'],
#  ['If I dont get back to you soon dont worry .'],
#  ["Three Darvocet in 1/2 hour didn't do a thing."],
#  ['6 more days of treatment to go and then maybe the oncologist will let us know if all this hell was worth it!'],
#  ['Crunchy salads with ranch dressing really hit the spot, as well as chicken pot pie!'],
#  ['You have had a rough ride to travel Carol, very rough.'],
#  ['I love you all and am very happy to be here with you.'],
#  ['I took it last week and it was 3.6.'],
#  ['You were kind to pass on the info to her.'],
#  ['Therefore, the chemo has been discontinued and the cancer is left to run its course.'],
#  ['That is what they did in 2006 on my left lung.'],
#  ['Just started taxotere and going for three shots after.'],
#  ['I lost my hair 14 days after the first treatment so I shaved it off.'],
#  ["Isn't it good to know that the person we are, does not consist of the sum of our body parts?"],
#  ['i just want to say i feel so bad for every person in these rooms everyone with this fight with cancer.'],
#  ['Right now my husband is doing his chemo still of cisplatin, taxol and 5fu and going thru hell again.'],
#  ['I know how terrible this damn disease is but keep the battle and I know I and many others are praying hard for you.'],
#  ['I have so many years left to work.'],
#  ['I still have one enlarged node which they say is scar tissue.'],
#  ['That is wonderful you both were best friends.'],
#  ['As I went out the door he said he was going upstairs to cleanup for his accupuncture which was for 9 a.m.'],
#  ['The site is still slow to sign into.'],
#  ['Of coarse I have been told that my next mri of the brain will be in conjunction with pci.'],
#  ['Demerol or mepergan fortis worked okay for me and my ensuing treatments were not as traumatic.'],
#  ['I hope everything goes well for you, and will remember you in my prayers.'],
#  ['I too am very concerned about taking tamoxifin.'],
#  ["Rare spot for cancer, but no spread (they didn't tell us they were watching some small spots in his lungs)."],
#  ['I have zero effect from surgery or the tumors.'],
#  ['To tell you the truth I felt some pressure with each poke but no pain.'],
#  ['You can get the number from the MD Anderson Web site'],
#  ['Thank you, for all you do to help other cancer patients by making these "blankies" for them!'],
#  ['Then I come home and nap for an hour or two.'],
#  ['She still has no movement on her left side.'],
#  ['Somebody also said when you have a biopsy it can spread cells within the lung.'],
#  ['I am sorry to hear about your mother.'],
#  ['There was a "disposible" turkey pan filled with caynenne pepper over oil facing my unit (dumpster to the side of unit) .'],
#  ['bone pain, lost of balance, flu symptons that lasted for days.'],
#  ['All they know is that people die from this disease.'],
#  ['A few weeks ago I got ill, very ill.'],
#  ['I received my port about 10 days ago.'],
#  ['a very special lady is having a very special day!'],
#  ['I was diagnosed with Stage IV Lung Cancer and have pleural effusion too.'],
#  ['He was in a coma for a month and a half.'],
#  ["I'm posting this list by my computer right now!"],
#  ['Unfortunately, he was not eligible for a clinical trial that is being offered at cooper, they combine standard chemo with Avastin (sp??)'],
#  ["Judy, please post and tell us what you find out at your doctor's."],
#  ["I've decided with a double mastectomy with immediate recontruction."],
#  ['I hate the taste of chocolate right now.'],
#  ['I have to apologize for seeming so abrasive in my previous post.'],
#  ['It was cancer and they removed almost all of my left lung.'],
#  ['I would suggest giving your self 15 minutes or an hour a day to cry your heart out.'],
#  ['I think this is the best posting on this site that I have ever read too!'],
#  ['Curious, my sister was left handed and had CA on the left side......'],
#  ["It's so sad to know that my husband dedicated 42 years of his life to NASA and this is the insurance they give him?"],
#  ['Tumors have shrunk or been stable now for more than two years.'],
#  ['I am HAPPY and RELIEVED for you, dear!'],
#  ['I will be following up with her if anything changes.'],
#  ["Don't blame you for your first thought though."],
#  ['Hi, Does it feel like you are wearing a bra even when you are not?'],
#  ["I'm trying my best to stay off of the grim sites."],
#  ['Is lymphedema common with the removal of lymph nodes?'],
#  ['My last CT scan showed very small tumors left in my upper left lung & adrenal gland .'],
#  ["Phil noted that most insurance companies won't readily pay for the test."],
#  ['I set the record for having 4 biopsies at once in their center!'],
#  ['In 2001, at age 67, I was diagnosed nsclc, stage 3a, inoperable/incurable.'],
#  ['OMG We are all on the same page, LOL'],
#  ["I've had my left upper lung lobe removed and am now going through chemo."],
#  ['Good Morning from cooold NH :) Happy to hear that you are doing better and your disability was approved.'],
#  ['My dad is in southern California receiving treatment from a local medical group.'],
#  ['He has been very sick on and off.'],
#  ['I am in bringing California red wine for celebration'],
#  ['You have had very good news I wish you the very best'],
#  ['Had port placed this morning,was scared but doing ok.'],
#  ["It was very uncomfortable to wear any bra (I don't wear underwire so can't speak to that specifically) by the end of my treatment."],
#  ['Please post to introduce yourself in a separate topic.'],
#  ['The more that report it directly to them I would think the more they would get busy doing something about it!'],
#  ['his liver enzymes are elevated also in lab work !'],
#  ['He was forced to rent a room from his ex-wife, in the house he purchased over twenty years ago.'],
#  ['Let me know if I can give you any info on my supplements.'],
#  ["I am sorry, But I meant to ask, Where is chat, I can't find a link to it."],
#  ["But thought since you have Colon ca on your Dad's side you should know they are related to breast ca."],
#  ['His cancer has is in the right lobe, left lobe lymph nodes, liver and bones of the lower back and hip.'],
#  ['He quit breathing that night and was put on a respirator and died 10 hrs later because his body completely shutdown.'],
#  ['If they get better, they can opt out of the program.'],
#  ['i was not offered any other rads options.'],
#  ["I'm wondering how long others have waited to have the repeat PET scan following treatment."],
#  ["I'm glad you posted and that it sounds like you're coping with the new drugs."],
#  ['I tried to reply but the site is being screwy...'],
#  ['You have some wonderful reasons to fight this awful dx.'],
#  ['I was in IV Stage Cancer when I finally said to myself, after layoffs at work and so on!'],
#  ['Just received my (free) second issue of CURE magazine and there are several excellent and hopeful articles on lung cancer.'],
#  ['Of course WE find you beautiful, gorgeous, whatever adjective you want/need~ but we never see you NAKED!!!'],
#  ['Your eyelashes are very nice and natural looking.'],
#  ['I have metastatic cancer to the lungs and have a prognosis of months.'],
#  ['Residues left on skin can cause the skin to burn.'],
#  ['So thank you and enjoy the holiday as best you can with those you love.'],
#  ['I have COPD and have beed advised I need a left lung lobe removal because of 2 small cancerous nodules.'],
#  ['We may look ok, and our voices may be strong, but our bodies know what this does to us.'],
#  ["I'm the one nibbling on that chocolate bunny!"],
#  ["I've been taking it for a month or so and my joints hurt really bad."],
#  ['The reason I am writing is due to the fact that my doctors act as though this is not real likely.'],
#  ["It's great that your doctor is  being cautious and doing the ultrasound."],
#  ["I've met lots of patients with lots of different things happening to them."],
#  ['I hope it goes well for you both.'],
#  ["So I sufferd terrible last tx and I don't want to go back."],
#  ['I know that I need to take this medication.'],
#  ['Stage III C at the age of 46.'],
#  ['Worst of all, these messed up cells can break off and plant themselves in other places and start dividing there.'],
#  ['It took me a few months after surgery to get to 2300 steady, so keep on keeping on.'],
#  ['My husband was also diagnosed with Stage 4 lung cancer, malignant pleura effusion, with mets to lymph nodes and liver.'],
#  ['My doctor found a relatively large lump in my left breast.'],
#  ["but I can't imagine what I would do without him."],
#  ['It will serve you better NOT to own cancer, for example it\'s "cancer" or "the cancer" but not "my cancer."'],
#  ['This has been a very hard subject since being diagnosed initially at 44.'],
#  ['I explained that my own self esteem would be challenged enough without seeing him looking at what I no longer had.'],
#  ['She had half estrogen+ tumor other  half neg-.'],
#  ['We sure do miss some of our oldies here.'],
#  ['I kept my eyebrows and eyelashes until just last week.'],
#  ['Sorry your mother has another infection to deal with, hoping they are able to clear it up quickly and proceed with her surgery.'],
#  ['She sounds very sweet and loves her mama very much.'],
#  ['(he quit smoking about 18 years ago) He has gone through 2 rounds of chemo.'],
#  ['I am finished with radiation treatment and can swear by Miaderm As the best.'],
#  ['I came to this site tonight looking for some hope.'],
#  ['You just cannot think about cancer every second and work!'],
#  ['He received 1 dose of Taxol but had a reaction so he only received the carbo.'],
#  ["I can do 27mins now and can't wait for this year's race this Sept. Chemo and radiation are a distant memory."],
#  ['my husband is also 47 we were hoping for the immuene trials for small cell.'],
#  ['although I noticed the hair on my legs is growing a bit faster.'],
#  ['I have talked to a surgeon 2 different times.'],
#  ['We achieved remission back in October 2016, five months after his diagnosis in May.'],
#  ['I decided to come here so you would all know I did not disapear!'],
#  ['Also, check with the oncologists who monitor the cancergrace.org site.'],
#  ['I had a shower and a two hour nap this afternoon in my own bed.'],
#  ['I know it is a hard road for you and hope for a positive response from this warden.'],
#  ['Wow, I was so apprehensive just an hour earlier that day.'],
#  ['I am worried about going back to work though.'],
#  ['Just wanted to add my welcome to this wonderful site of awesome sisters.'],
#  ['Everyone here is really great and I look forward to hearing from everyone and getting to know you all.'],
#  ['There was NO cancer left after my chemo!!!!!'],
#  ['My breast surgeon also did not want to do a PET since they pick up too many hot spots.'],
#  ['This is a nasty disease and we can only hope and pray.'],
#  ['She had CyberKnife done and was told in December that the tumors were shrinking and cells were dying.'],
#  ['Several of those are on the recommended list to help FIGHT cancer!'],
#  ['Now with no estrogen in my body the hot flashes are much worse so do I blame Arimidex??'],
#  ['And I pray for strength & healing for you & him, in the name of JESUS, Amen.'],
#  ['This includes age, other health problems, er status, tumor grade, tumor size, node involvement, hormone therapy, and chemo regimen.'],
#  ['Appears your mom is a strong fighting woman and this is real good .'],
#  ["I don't have any thing to add, only more questions!"],
#  ['I know chemo is horrible, but, you are almost done with it forever!'],
#  ['I thank you all very much for your sharing your stories and for your input here.'],
#  ["I've had radiation 5 years ago so i know what to expect but chemo is new to me and I am scard."],
#  ['The wait was killing me and then I get to the Dr. and they forget me.'],
#  ['She thought that using lots of sunscreen, way more than usual, would prevent it.'],
#  ['I wanted to thank you all for all your kindness and prayers through out this battle.'],
#  ['Those words do something negatively to my body.'],
#  ['Then my intestine was so damaged, I got severe diarrhea.'],
#  ['At that time they did a chest xray & ct scan & said I had cancer in my right lung.'],
#  ["Add to that the fact that I just miss him, my best friend for the past 30 years, and that's lonely."],
#  ["I've gotten great suggestions from this group and am hoping for more."],
#  ['I was dx with Adenocarcinoma and had a lobectomy of my right upper lobe.'],
#  ['After a couple of scans and a biospy, she beagn treat in early April.'],
#  ['Also very happy that he is eating now and wow seeing his patients.'],
#  ['If these doctors are so uncaring, do you not have other choices.'],
#  ['Do you know of any insurance companies that work with survivors?'],
#  ['The tumor was on left lung, in lymph nodes, in lung and wrapped around aorta artery.'],
#  ['Handled rads fine although most of my energy left me.'],
#  ['wow full plate, good luck, good thoughts coming your way'],
#  ['Moderation is the key (not that I follow that, I eat whatever the heck I want to eat :-)).'],
#  ['My husband was recently diagnosed with bladder and lung cancer.'],
#  ["And, as was already said, it seems like you DO care, it's just a matter of timing!!"],
#  ['I had a lumpectomy, but, wanted to wish you good luck in your decision!'],
#  ['A social worker also made a visit today.'],
#  ['My tongue feels like a cat tongue and my lips are dry.'],
#  ["I've been taking it for 16 months so far with no side effects of which I'm aware."],
#  ['It cost me $5.00 for a 30 day supply through my Kaiser Health Care plan.'],
#  ['Hi, I had my upper left lung removed 9/04.'],
#  ['Taxol was not as tuff just sooo long.'],
#  ["I didn't post before because this isn't about my breast cancer."],
#  ['By week five he was in the hospital with a blood clot in one lung and a pleural effusion.'],
#  ['It is probably the best thing for you, have you read some of the new letters on the net?'],
#  ['I also have swelling/fluid in my left armpit.'],
#  ['Being in tune with what you experience enables you to advocate for yourself.'],
#  ['How insensitive of her to ask all those personal questions.'],
#  ["Thank you Rena, I'm glad you have found strength and wisdom in all this."],
#  ["I can't imagine having rads on your lip and chin."],
#  ['Saline spray really helps with a dry nose, so, it might help with the bleeding too.'],
#  ['They dont show how hard it is for some of us and our families.'],
#  ['If you want more info on Taxotere, Chemocare.com is an excellent site for info.'],
#  ['He said that he is worried about the primary cancer in her lung.'],
#  ['Their suggestion is to walk around, take deep breathes and cough up what ever he can.'],
#  ['Also, what type of clinical trials are they looking into?'],
#  ['I thought it was over when they told me that they had the whole thing.'],
#  ['I do have bone pain for about a week after.'],
#  ['Thank you Katheryn for your post and support.'],
#  ['If you have any specific questions, please feel free to email!!'],
#  ['The doctors were saying she might have lupus.'],
#  ['I appreciate your response, it makes me feels better.'],
#  ['The biopsy showed its origin was my lungs, but there were no lung tumors to be found.'],
#  ['Your surgeon should give you exercises to do.'],
#  ["Also, she's had terrible diarrhea and stomach cramping."],
#  ['Presurgical MRI showed a spot deep in the left breast.'],
#  ["I wish you and your family lots of love and I'll pray for you."],
#  ['It was very large, in left lung, on lung, in lymph nodes, wrapped around aorta artery and pushing against my esophogus.'],
#  ['Number one, do NOT listen to statistics.'],
#  ['Here is best site for your moms condition'],
#  ['Drugs that are most effective in killing the cultured cells are recommended for treatment.'],
#  ['i so wish he had left it in.'],
#  ['1998 stage 1, left breast, this year stage 3 left breast.'],
#  ['Glad the decisions are made, and you are on your way.'],
#  ['I hope this goes smooth for you and that all outcomes are great.'],
#  ['I am so scared that maybe my onc is wrong.'],
#  ["I don't understand why they aren't doing a biopsy yet, that's what I would ask for."],
#  ['All breast cancer patients are considered innocent victims while many people assume Lung Cancer patients caused their disease by smoking.'],
#  ['Thank you do much for the beautiful ornament.'],
#  ['Anyone else have this after radiation treatments were done?'],
#  ['Happy Birthday to you, Happy Birthday to you, Happy Birthday, dear VickiSam, Happy Birthday to you.'],
#  ['A very touchy subject in deed and very interesting point.'],
#  ['He is also going to travel to Vanderbilt University where they have clinical trials for this exact type of cancer going on.'],
#  ['I am Stage IV, non small cell lung cancer.'],
#  ['Was the first time I cried since this began in february.'],
#  ['My mother was diagnosed two months ago with adenocarcinoma in the left lung.'],
#  ['My grandaughter is 16 and she is having a hard time dealing with my husband, her grandfather having lung cancer.'],
#  ['A person can sign on when they have 6 mos or less left of their life.'],
#  ['After I completed chemo I had 30 days of radiation to my chest area.'],
#  ["and just now thought of this: They will probably require a drug test (it's a local govt agency)."],
#  ['Positive thoughts and prayers and this site are getting me through this time.'],
#  ["You are one strong person, that's for sure."],
#  ['People prayed for me every hour of my surgeries and I found it so comforting !'],
#  ['Looks like I left Walnut Creek too soon!!!'],
#  ['I think I moped for 2 weeks after I heard you were having problems again.'],
#  ['Happy Birthday to you, Happy Birthday to you, and many more!'],
#  ['I hope you can find comfort and peace while you are there.'],
#  ['I wish you a speedy time with chemo and hopefully you will feel fine!'],
#  ['It sounds very much like you are seeing the beginning.'],
#  ['But I know that this weight HAS to come off.'],
#  ['So far it has prevented getting mouth sores.'],
#  ['Hope it all goes quickly and easily for you.'],
#  ['It is easy for someone to tell you not to fret over it, since nothing can be done until Monday, but that does not help!'],
#  ['Babe said it happened that way with her also.'],
#  ["It's OK to lean on us, so that we can help to hold you up, support you."],
#  ["She said he's had the flu on and off for awhile now, and he is tired a lot."],
#  ['Furthermore, I hope you both find support in one another.'],
#  ['To best answer your question if NSCLC can go to the colon, the answer is yes.'],
#  ['He does not want to eat some special food at all, especially.'],
#  ['I just wanted to say that you are a very strong person.'],
#  ['When we first found out it was cancer (just not what type)June 5th, I thought I would die.'],
#  ['Others though, were led over to Satan who threw them into the burning pit.'],
#  ['May He bless you for being there for her.'],
#  ['I would always try all means neccesary to escape a doctors prognosis, so yes Chemo is worth it.'],
#  ['Not that Moopy could really refuse, being half sedated and flat on her back.'],
#  ['from a 2 year survivor (well, at least I will be come August 2, 2008).'],
#  ['But that is something you will have to work out yourself.'],
#  ['he will start feeling better after the 4 days off rad.'],
#  ['Somehow I managed for the last 18 months with one year of chemo and radiation.'],
#  ['This little hospital here almost killed me when my appendix perforated last year.'],
#  ['I wish you to get through this procedure and be ready on Feb 25 as you plan.'],
#  ["He is diabetic and he doesn't like doctors either."],
#  ['But it does give you time to prepare.'],
#  ["the foam rings don't sound like much fun."],
#  ['Dr said the is a 40 percent chance for malignancy.'],
#  ['we are quite shocked right now, so any help will do.'],
#  ["I'm still in limbo but feel good about my case being brought in fron of 8 other oncologist."],
#  ['And believe me, that tape left itchy spots when they removed it!'],
#  ['The tumor was small and growing very very slowly.'],
#  ['I hope you feel BOTH, more at peace, and more calm!'],
#  ['We are happy to announce that as early as tonight, a new Chat application is being launched on CSN.'],
#  ['I will be praying for you, that God will help you through this time.'],
#  ['Your eyelashes do grow back quickly and usually very fast.'],
#  ['Today I find out that I have cancer cells in the fluid.'],
#  ['So EXTREMELY happy for you, NED is someone we all want to have and hold on to good for you!'],
#  ['It must be very hard to be 22 years old and going'],
#  ['Some are fairly slow and double every 210 days.'],
#  ['There is absolutely no way I could have worked while receiving chemotherapy or radiation therapy.'],
#  ['By the way, Biotene worked wonderfully for me.'],
#  ['Two months later, I had ten radiation treatments (5 on, 2 off) and twelve weekly 1 1/2 hour chemo treatments.'],
#  ['Did they give you any pain med prescription before you left the hospital?'],
#  ['SO I posted a pic of me on my blog too!'],
#  ['I had to have taxatore and no nothing else about any other chemo or meds.'],
#  ["I've been with her for 2 months, 24-7 and it's been overwhelming."],
#  ['yes my neck face very dry very itchy like sandpaper use alot of moisterizer.'],
#  ['I am in remission from sclc but the great chance of it going to my brain concerns me.'],
#  ["I have never had one so I can't relate to the confinement, noise etc."],
#  ['I let my internist review all the lab work.'],
#  ['We also have a right to have joy!'],
#  ['I certainly hope they can help you without your having a mastectomy.'],
#  ['Now all I can do is wait for pathology reports.'],
#  ['The university teaching hospitals with cancer centers tend to be on the cutting edge.'],
#  ["I'm having a bleeding left eye during my IBRANCE treatment."],
#  ['I also found peppermint and ginger was soothing.'],
#  ["The Dr told me that he couldn't tell on the PET Scan because the brain normally lights up with activity."],
#  ['Give them only the information they need to know.'],
#  ['I have posted before but rarely get a response.'],
#  ["I used my old shirts and my husband's too."],
#  ['Every once in a while you just have to scream!!!'],
#  ['Sometimes your own insurance company offers free second opinion services.'],
#  ["Anyone else I'd love to hear your input as well."],
#  ['We loved ice cream, so during the trip over the mountain(40 minutes!)'],
#  ['My husband was on alimta for several rounds.'],
#  ['What I really meant is that they talk *from* statistics (e.g.'],
#  ["If cancer, won't it get bigger in 2 months?"],
#  ['My husband, a family member or friend has been driving me which I so appreciate.'],
#  ["Sounds like they're gonna fix you up 'ol boy!"],
#  ['What stage is your Mom in and does she have cancer anywhere else?'],
#  ['WHY WOULD YOU BE IN A CANCER SURVIVORS NETWORK YACKING ABOUT SMOKERS....'],
#  ['It is so good to follow our hearts and make our own choices.'],
#  ['But my cancer also spread to my brain.'],
#  ['Could I get spoiled YES, LOL Love to all of you'],
#  ['I have used this site to answer so many questions.'],
#  ['You will find lots of support & info here.'],
#  ['My hubby is making the chili, so, YEH for that.'],
#  ['I hope that good news continues to come and I will keep you in my prayers that this is so.'],
#  ['sucking on ice also helps with mouth sores!'],
#  ["I am so sorry about your dad's diagnosis."],
#  ['Next Monday he has another CT but we do not get the results unti,l the following Monday.'],
#  ['The cancer is in her left lung and has spread to local chest lymph nodes.'],
#  ['My dad would call me about storms as well, along with rain,snow etc.'],
#  ['You have expressed so many of my exact thoughts, and everyone here is a part of my giant, warm, cuddly blanket.'],
#  ['Let us know when you are able how it all turned out.'],
#  ['You will be done before you know it.'],
#  ['I am currently 4 months since my last chemo and getting compliments on my hair just about daily.'],
#  ['Anyone else out there have a similar experience?'],
#  ['I was ordered to have 33 treatments, after 22 my skin looked like I had walked through a fire.'],
#  ['Truly amazed with the generous nature of the people around me and pretty dissapointed with about everything else.'],
#  ['Reading your post will make my next hour a happy one!'],
#  ['Why did they do a lymph resection in her left arm?'],
#  ["I didn't know if you have a support group of bc survivors in your area or not."],
#  ['She also "glued" the opening together , no stitches or clamps.'],
#  ['Your a very in tune with your body at a very young age, I wish I had been.'],
#  ['Reading helped me by letting me know that many folks learn to live with cancer.'],
#  ['He has stopped it for 3 weeks, and then we can talk about it.'],
#  ['I had a mastectomy of the left breast and immediate reconstruction this past January.'],
#  ["It's a more active web site for lung cancer."],
#  ['Many times we received denials and everytime it was due to a bad code used.'],
#  ['This weekend I had the privilege of participating in a program called "Casting for Recovery".'],
#  ['he had tumors in both his right and left lung.'],
#  ['Keep on top of any side effects before they become too bothersome.'],
#  ['I love this site and I love everyone of you.'],
#  ['give her all the love and support u can.'],
#  ['Hi, it was good to read all of your post.'],
#  ['It never got worse and is still about the same.'],
#  ['But, if you are still worried, you need to go talk to your oncologist or get another or second opinion.'],
#  ["I sometimes can't sleep either thinking about my bc."],
#  ['to hear that you and your Mother are going thru this.'],
#  ["I've only known her for a year and a half since my hubby died, but just can't believe she's gone."],
#  ['The only thing that is known right now is that the lung cancer is much more aggressive than the kidney.'],
#  ['It has been hard, but well worth it.'],
#  ["Then, the pain/numbing medicine ball with catheter finished and I was told to pull out the catheter, I'm expected a couple of inches."],
#  ['Get it checked out and talk to the hospital social worker about getting help with medical costs.'],
#  ['I know what you mean by the funny looks I got from coworkers.'],
#  ['Hi I had the VATS lower left lobe lobectomy on Dec. 1/10.'],
#  ['Dress warm and no zippers, the room where the scanner is has to be freezing cold.'],
#  ['If you decide Not to visit, you will regret it later.'],
#  ["If you got your hair back after chemo, and your hair is thinning, I imagine it's from lack of estrogen."],
#  ['I am working half days and finally sleeping better.'],
#  ["Chemo doesn't get in there too well because of the loss of blood flow."],
#  ['Many people will be drawn to you because of the special and loving person you are.'],
#  ['I took tamoxifen for complete 5 yrs (2 lumpectomies one time caner) I did have hystertomy due to the MED (3 yrs ago)'],
#  ["He requires almost constant care, and I'm doing this basically by myself."],
#  ['I will be starting my chemo march 8.'],
#  ['of Radiation and the one who has treated me.'],
#  ['I am going to youtube it today.'],
#  ['In the mean time the waiting period is tourture.'],
#  ['Just received news of small cell lung cancer.'],
#  ['I am on Tarceva and am also interested in any discussion re this drug.'],
#  ['Yes my eyebrows came back very quickly'],
#  ['Sometimes I wish I would die as well.'],
#  ['I hope all your dreams are coming true, and your are thriving in great health.'],
#  ['I told my plastic surgeon that I wanted 2 perky boobs.'],
#  ['Well I went to the surgeons this morning and he reoved my port.'],
#  ['I use a razor blade and love it.'],
#  ['She said she is not afraid to die.'],
#  ['I am newly diagnosed at the age of 43.'],
#  ['Had Pet-scan last tuesday which also confirmed the left lung but hidden is a small nodule on my right lung.'],
#  ['They put in a chest catheter and have drained over 5 liters of fluid over the last few days.'],
#  ['When you love someone you feel their every blink.'],
#  ['She raised a wonderful daughter, please remember the good times that make you smile, she will forever live in your heart!'],
#  ['My wife lost her battle this week so I understand your loss.'],
#  ['He most recently had this CEA test also.'],
#  ['It is located in the lower lobe of my right lung.'],
#  ["That's because it is not definitive due to the odd test results."],
#  ['And yet, when I think I am being helpful and perhaps even poignant, when I hit "submit", presto-bingo, it disappears altogether!'],
#  ['But if I needed one during the day, I took it.'],
#  ['I hate that at the tender age of 46 you have experienced all that.'],
#  ['He has been running a low grade temp (99 - 100) off and on.'],
#  ['His doctor said his lungs are clear, but his pressure is a little low and his blood levels are low.'],
#  ["I'm 48, was diagnosis DCIS in May in my right breast and had a double mastectomy in June."],
#  ['They manage side effects or secondary conditions as they arise.'],
#  ["I can't sleep and my mom noticed my weight loss."],
#  ['Hope you had a wonderful & blessed day full of Love and Joy.'],
#  ['I healed very well and no infection after four surgeries.'],
#  ['Welcome to the club nobody wants to belong to.'],
#  ['The last PET Scan he had (2 weeks ago) showed that the cancer is almost completely gone.'],
#  ['I just came to this site to possibly get more info on recovery after a lobectomy.'],
#  ['I just saw my onc today, and left upbeat.'],
#  ['Its weird but all lab work and mammograms are clear'],
#  ['You can be a great help to your Nan and help in her battle with cancer, you can be part of her cure.'],
#  ['They will teach you exercises to do and will teach you how to do lymphedema massage.'],
#  ['that whatever you want to do is possible.'],
#  ['The lump became more prominant after she stopped breast feeding.'],
#  ['I am at a loss as how to help her.'],
#  ["Happy Happy Happy for you Cousin, Your news couldnt be any better, Go Get'm Tiger -"],
#  ['Listen to your body and strike a balance between the exercise you need/want and what the body will take.'],
#  ['We have fought a huge battle and WON!'],
#  ["I'm so-o-o-0 much better today, and I don't have to face another infusion until next Tuesday."],
#  ['I get lab work done before each appt.'],
#  ['I had a bi-lateral masectomy in March of this year and the pain shoots across all the time.'],
#  ['Someone brought up hair loss (impending) and I wondered if there were suggestions for hat/scarves or wigs.'],
#  ['If you want to e-mail me my e-mail is EMAIL.'],
#  ['They all have debunked the so-called "cancer" diets.'],
#  ['I began having pain in my mid back radiating down my left leg.'],
#  ['I could see the tumor, which he described as fluffy.'],
#  ['Wishing you all the luck and faith there is.'],
#  ['Please consider taking a mild antidepressant if you are not already taking one.'],
#  ['Once the tests are done, sit down with a doctor that you trust, go over options, research it,and call your local cancer research center.'],
#  ['She actually was quite the hypochondriac until two years ago.'],
#  ['Of the four, only KRAS does not have a targeted therapy yet.'],
#  ['One gets sick and tired of being sick and tired.'],
#  ['And the doctors say, "learn to live with it"????'],
#  ['Do they both make your eyelashes and eyebrows fall out?'],
#  ['My first recurrence was a  tumor in the axilla.'],
#  ["You will have your days, but don't forget about the finish line."],
#  [":) I'm up for a virtual party as well, sounds like a load of fun :)"],
#  ["thanks for you ideas and encouragement, I wish my dad could get on this website, but he's not computer savy."],
#  ['Enjoy it, you worked hard to get there.'],
#  ['My daughter was diagnosed  a couple of years ago with DCIS but opted not to have radiation.'],
#  ['First the Hilar Lymph node biopsy this Friday, then full node evaluation and wedge resection if NEGATIVE?'],
#  ["you do make me laugh so hard at times, please don't stop..."],
#  ["I've been told that about 40% of the women that have the tram wind up with a hernia."],
#  ['ALTHOUGH YOU ARE FACING A TERRIBLE SITUATION, THERE IS HOPE.'],
#  ['The best thing "in my opinion" at this time  is to be there for him with love and understanding.'],
#  ["She's due for scans at the end of the month, and hopefully the scans will show that it is under control."],
#  ['However, after this long battle of his and ours, he is slipping, His looks are changing, he is tired and not eating well.'],
#  ["Wishing you all of best and we'll all be here for you it's a great bunch of people to get advise from Keep in touch."],
#  ['I had more chemo and radiation, I AM IN REMISSION..'],
#  ['Thank you quail for your service and please pat yourself on the back for me for doing what you do in the first place.'],
#  ['I also use plastic silverware and have not had any metal taste at all!'],
#  ['He has lung Squsmaous cell, BAC and Carcinoid tumorlet all in his upper left lung..'],
#  ['I also had my entire left lung removed on July 31, 2007.'],
#  ['Has anyone heard/experienced NSLC spreading to the ovary?'],
#  ['Rememembe always that you have a team here that is watching your back!!'],
#  ['Just because I have cancer twice now and my personal life is the pits, well it does not mean I get on the pity bus.'],
#  ['I bet we all left cookies for santa disneyfan.'],
#  ["The people I have talked to haven't had lung sugery."],
#  ['What do you think , that the single lung nodule that was taken out by Vats surgery was a simple inflamed lymph node?'],
#  ['They can shoot up for many, many benign reasons.'],
#  ['I am not afraid really anymore about the chemo.'],
#  ['The cure word from the dr is very encouraging.'],
#  ['I had my entire left lung removed in Dec. 2004.'],
#  ["Some are highly aggressive and double every 22 days (I've heard of aggressive breast cancer that was this quick but that's rare)."],
#  ['My eyelashes thinned out considerably and my eyebrows stayed the same.'],
#  ['I found the lump on my left breast dr found another one.'],
#  ['Just describe what you described so very well here.'],
#  ['I am only 57 and have a whole lot of living I still want to do.'],
#  ['Thank you for taking the time to write me back.'],
#  ['Also my dad recently lost his voice has 4 lymphnodes pressing on left vocal cord, did the rad.'],
#  ['I am for anything that will improve our odds.'],
#  ['Thank God it healed over, for if it could have been very serious had my colon perforated.'],
#  ['The medication I took for acid reflux caused diarrhrea so I stopped taking it.'],
#  ['I hope that is a positive sign as this is his fourth line chemotherapy and none of the others really helped the coughing!'],
#  ['My dads cancer has remained confined to left lung.'],
#  ["It's great for us that are in the midst of treatment to hear stories like yours."],
#  ["He's my son's almost 3 year old yellow lab and he is so much fun."],
#  ["The Physiatrist is saying it's neuropathy and has put him on neurontin, but I don't know because it's not helping much."],
#  ['On way home about an hour from chemo dr.'],
#  ['I was stage 3, (lump was 2.5 cm) and also her2 pos.'],
#  ['What about popular alternative treatments circulating on social media??'],
#  ["That under the facade of 'normal' these people present, there is always something."],
#  ['You get yourself all pampered by that hubby of yours!'],
#  ['I am so happy that the tarceva is working.'],
#  ['6/15 nodes were positive after her modified radical left mastectomy.'],
#  ["I was panicked that I couldn't catch my breath at times."],
#  ['I had a lower right lung lobectomy via the vats procedure, and that was on 9-23-10 and I have been fine.'],
#  ['aww your daughter & granddaughter sound like sweet hearts.'],
#  ['Get a second opinion at a teaching hospital.'],
#  ['I am thrilled to hear this news ... !'],
#  ['but the word that really gets me is "Remission", Ugh!'],
#  ["I have not received the numbers for what stage my cancers are at yet, haven't asked yet, as they are only numbers to me."],
#  ['Did 6 courses of Taxol and Carboplatin, rough chemo.'],
#  ["If you haven't already done so, also use the CSN search engine for terms like adenocarcinoma of the lung."],
#  ['I hope you are feeling better after your meltdown.'],
#  ['There are still times i get scared and depressed but nothing like I did.Places like this helped also.'],
#  ['This is one messed up roller coaster ride we are on.'],
#  ['Anyway, i have gained lots of experience over these past years, so please feel free to ask for advice.'],
#  ['I had 0 Stage, DCIS and ended up with a contralateral mastectomy.'],
#  ["There wasn't a hair left on me anywhere."],
# ...
#  ["Be aware that cancer isn't cancer until the pathologist sees it under the microscope."],
#  ['I can honestly say that the lung itself was never really too painful.'],
#  ["They tried Taxol on me but I'm allergic to it & they couldn't use it."],
#  ['A lot of us have been thru radiation, so, we will help you get thru it.'],
#  ["I'm very happy for you that they were able to remove it."],
#  ['It truly is not fair, but I know you will continue to fight.'],
#  ['His breathing sounds like ice in a blender on high with every inhale/exhale.'],
#  ['had surgery for lung cancer in feb 2008, all seemed ok, then it hit me.'],
#  ['Great news and double Great news at that!'],
#  ['My drain tubes were left in for about 4 1/2 weeks.'],
#  ['Can anyone give me your personal experiences with taking avastin and or knowledge about avastin.'],
#  ['This is no longer an automatic death sentence.'],
#  ['May God give all of you comfort, courage, love, healing and the will to get past this disease and conquer it.'],
#  ['I can tell it is swollen because it gets bigger than the normal breast when it should be smaller because of the surgeries.'],
#  ["I don't have any answers for you, but I think on that web site they will."],
#  ['Yesterday they told me they didnt see anything which brought tears of joy, but also a wave of fear.'],
#  ['Sincerely sorry for the loss of your Dad.'],
#  ['My heart goes out to you and I can feel your pain coming through.'],
#  ["Friends and family don't always understand the way we feel."],
#  ['My eyelashes were still coming out months after chemo.'],
#  ['I stood up and hopefully made a difference.'],
#  ['What makes him not want to take any kind of treatment?'],
#  ['I have alot ahead of me I am on the tail end of chemo , but need two surgeries then rads.'],
#  ['will have left mastectomy within next ten days.'],
#  ['I am just trying to feel better overall.'],
#  ['Please focus and take care of  yourself, you just back from the surgery, and need rest.'],
#  ["Keep it up, but make sure you don't burn the pate, it hasn't see sun in so many years, it could burn real quick."],
#  ['some times you have to take it one hour at a time.'],
#  ['But i was struggling with my breathing, tiredness and just feeling bad.'],
#  ['We on this board know about the waiting and the myriad of emotions one goes through, so let us wait with you.'],
#  ['It will show if she has any active cancer .'],
#  ['I lost 99.9%, did not lose eyebrows or lashes.'],
#  ['Tell me about the surgery and the recovery time.'],
#  ['My Mum was diagnosed with stage 4 non small lung cancer last August.'],
#  ['Does anyone know about this 1/2 hour chemo program and if it does or does not work.'],
#  ['I am sure that anyone who has had a mastectomy feels this way.'],
#  ['It is mostly on one lung except a lymph node on the left side.'],
#  ['Pancoast is what I fear is causing my shoulder pain.'],
#  ['I will pray the clinical trial comes through and starts to shrink those terrible tumors that causing you so much pain.'],
#  ['I am just so in the dark about all of this.'],
#  ['However, adenocarcinoma of the left lung has completely shut down my left lung.'],
#  ["That's standard practice and it doesn't mean that the spot is or isn't cancer."],
#  ['They got the whole tumor, however 5 if 5 lymph node were involved with free floating cells within the lobe.'],
#  ['That is wonderful news breath a sigh of relief'],
#  ['her posts have brought me a lot of information and inspiration.'],
#  ["Doc said it was the best possible lab results considering it's cancer."],
#  ['Have any of your doctors offered anything to help through the rough spots?'],
#  ['He has gained back 20 pounds and has no pain anywhere.'],
#  ['I normally just leave this stuff on my blog (the CSN one).'],
#  ['My class is going to be stoked when I tell them.'],
#  ["I quit 7 months before diagnosis, wasn't soon enough."],
#  ['I was diagnosed with BC in left breast and some lymph nodes.'],
#  ['I would go in there and pretend that it was a game of pac-man and the drugs were gobbling up the bad cancer cells.'],
#  ['You may want to talk to the doctor about the purpose of radiation.'],
#  ['The first cycle of Taxol, Carboplatin and Avastin worked briefly.'],
#  ['There is a man who contributes to the inspire website who contributes regularly at 13 years +.'],
#  ['come here and check in you will find lots of support.'],
#  ['You were a strong wonderful Man,and an example to other Men with BC.'],
#  ['I also have a family history of breast cancer 4 of us, my mom.'],
#  ['I went for the implants and have some feeling post surgery 2 months on the right.'],
#  ["Hmmmm, I can't believe noone has any opinions or info about this.."],
#  ['Tell your mom to keep good spirits and give her lots of support  and I feel that she will beat this.'],
#  ["You didn' say what lobe they were taking out or any other details."],
#  ['Someone in the hospital can direct you to them.'],
#  ['(a good idea at this point) Initially, I consumed gallons of instant breakfast products, and ice cream.'],
#  ['nothing for me to add as no experience with rads yet.'],
#  ['This is all very new to us and very difficult and confusing.'],
#  ['After two or three days of not wanting to eat, one bite went in and then everything came .'],
#  ['I hope your day is full of love, cake and balloons!!'],
#  ['Start a journal about what he says and the way he treats you, you may need documentation in the future.'],
#  ['She never complained even through some terrible side effects, She always looked ahead.'],
#  ["is it true if the fluid is malignant the patient doesn't live long at all??"],
#  ['I mostly sleep in an upright position either with lots of pillows or the recliner.'],
#  ['This will always be a joyus season for you.'],
#  ['I suggest that you sign up on the Ispire web site also.'],
#  ['We have a wonderful group of ladies & some men here.'],
#  ['Do they have clinical trials up your way?'],
#  ['Which I have no problem with at all.'],
#  ['I am on low dose chemo they say.'],
#  ['These were not a severe as my first chemo, and for me they worked almost immediately.'],
#  [' thanks for your wonderful words of faith, I too came to the conclusion" why not me?"'],
#  ['I had VATS so my recovery was fairly fast.'],
#  ['My dear dad passed away yesterday from lung cancer.'],
#  ['What are the programs for stretching the dollars for folks undergoing hard times,where do I find this out?'],
#  ['I have had 2 kinds of cancer and both times I felt tired and sick before diagnosis.'],
#  ["We�want to know how you're doing and wan to�keep up with you."],
#  ['Her oncologist said *6-9 months* with NO treatement.'],
#  ['I have pain pills left from my double mastectomy.'],
#  ['I am no expert in this but you may want to ask the doctor if it will help at all.'],
#  ['I am staged at a 1b at this time but he says that could change depending on what they find.'],
#  ['I was disabled due to a back surgery gone wrong, and left unable to work.'],
#  ['I have my last Taxol treatment next Monday.'],
#  ['My right breast completely lacked the mammary fold and basically had a hard ridge of tissue.'],
#  ['Sometimes another biopsy is required, but before you have the Dr. do it, sit down and ask him all these questions.'],
#  ["I was 33 at diagnosis and had a large tumor and 4 + nodes and wasn't at all sure that I would see 43."],
#  ['Mine are fairly well used so the strap does not bind.'],
#  ['Does anyone have a recommendation for an MD Anderson oncologist that specializes in lung cancer?'],
#  ['Thank you for being our champion, on this day and in this event and always!'],
#  ['My tumor turned out to malignant after my second biopsy.'],
#  ['It was all overlooked by the doctors for months.'],
#  ["I'm sooo happy for you, that is awesome news, congrads!"],
#  ["The doctor reminded all of us of the big picture, saying how well she's doing now compared to back in May/June."],
#  ['Always think positive, like the glass is half full instead of half empty.'],
#  ['Right now you need to focus on yourself and should not feel guilty by any means.'],
#  ['I am A former smoker (quit 20 days ago) age 22 and diagnosed with an incidental 4mm lung nodule.'],
#  ["My doctors prefer the phrase 'no evidence of disease'."],
#  ['his last threee chemotherapies have been cnacelled because of shingle, or dehydration, or low hemoglobin levels.'],
#  ['I do take ibuprofen with the hydrocodone, hoping it will help with muscle pain too.'],
#  ['Just remember to get up and walk with help the first few days and do the breathing exercises.'],
#  ['You were one of my first friends on this site back in 2009.'],
#  ['You are a child of a loving creator who has sought to present you with a challenge.'],
#  ['Will Santa give him/her special toys & treats?'],
#  ["Some people can't function well knowing they have cancer."],
#  ['At least I will be able to start the exercises tomorrow.'],
#  ["I'll be thinking about you tomorrow morning and also look forward to reading how well it went for you."],
#  ['I bought the "mini net sponge" at Walmart for 78 cents a piece.'],
#  ['What a sweet surprise to find those lovely gifts and letters waiting for you!'],
#  ["Just one little prick, and that's it."],
#  ['Try chemocare.com lots of info on all types of chemotherapy.'],
#  ['Congrats to you~ you deserved that glass of wine Big Time!!!'],
#  ['Please keep the faith that God will see you through this stage of the journey.'],
#  ['Both of my doctors wanted to start chemo right away.'],
#  ['I will pray your rad treatment eradicate that a troublesome area.'],
#  ["We talked about how we'd sit and hug and love each other like we did when he was here."],
#  ['For the mouth ulcers I used Ulcer Ease.'],
#  ['I had immediate tram flap reconstruction after my left mastectomy.'],
#  ["Thanks for sharing your neice's blog link."],
#  ['I am hoping that your surgery went well and you will be'],
#  ["I too didn't loose all my eyebrow hairs or eyelashes they just thinned."],
#  ['It was nice to not feel so overwhelmed like we did when we were at Moffitt.'],
#  ['I had breast cancer in 1989 And a double mastectomy, then breast cancer again in 2000.'],
#  ['Sadly, she had to put her beloved little doggy down this afternoon.'],
#  ['Plus you can pick up great and useful information from people who have been through similar things as you.'],
#  ['Your mom is very fortunate to have such a wonderful daughter to stand by her.'],
#  ['So, you go girl and our prayers are with you and your family as well as with everyone.'],
#  ["I've been under the chemo weather this past week, and finally figured how to get a baby photo up this evening."],
#  ["Just wanted to say I'll be thinking and praying for you."],
#  ['It was already Stage IV (one bone met to the left sacrum).'],
#  ['With�you having to have more test things may not be as bad as we always think.'],
#  ['He actually told my sister and daughter it was a surgical cure?!?'],
#  ['Everyday we hear of someone who has been diagnosed with cancer, and were are a very small town (11,000).'],
#  ['I am both a stage one breast cancer survivor(2002) and a stage one lung cancer(2006) survivor.'],
#  ['Lots of problems with swelling on both sides'],
#  ['It hurts so much to see his body gets weaker and weaker everyday.'],
#  ['They also gave a dose to the site where the large one was removed.'],
#  ['For mouth sores, they make a mouthwash that you can swish and swallow.'],
#  ['The sample is then sent to a pathology lab for analysis.'],
#  ['at first they they thought I was HER, but then did and additional test and found I was'],
#  ['I worked full-time during rads'],
#  ['She had a full hysterectomy but declined any conventional treatment, despite a good prognosis with such treatment.'],
#  ["If I'm at home I whip off the wig , cool off and put it back on!"],
#  ['You too are in my prayers and I thank you for sharing your HOPE with me.'],
#  ['my father is currently looking at having his left upper lobe removed for a 1.2 cm'],
#  ['Looking back at all we have over came as a family I have learned this,'],
#  ["I have my good days and bad days-since chemo I am now post menopausal and don't want to take estrogen replacement."],
#  ['I started having real bad pain in my left wrist in May.'],
#  ['I pray that she will eventually come around and go thru with the treatments.'],
#  ['wow so great to hear you are feeling well.'],
#  ['Get doctors you know will fight with you!'],
#  ["I truly believe what you are saying, I've heard people say WHY ME???"],
#  ["I guess what I'm saying is thank you for validating my fluctuating emotions right now."],
#  ['Please do this for your own�peace of mind.'],
#  ['So very happy for your Mom and you.'],
#  ["If you do end up going to CTCOA for a second opinion, I'd love to hear what you think of their operation."],
#  ['My grandpa, her dad also died of lung cancer, also at age 54.'],
#  ['If you live in a town with a good breast cancer clinic I think I would take her directly there tomorrow.'],
#  ['It is always disheartening to read of someone getting cancer again.'],
#  ["But it sounds like you're one heckuva strong lady"],
#  ['Been to Schroon Lake, Lake George, Lake Placid, Old Forge, and Saranac Lake.'],
#  ['It really needs to be a team effort to stay off the cigs!!!!!'],
#  ['Everytime I would rinse my mouth chunks of my tongue would fall out.'],
#  ['We are sooo glad that you found your way in here!'],
#  ['I watched my father in law die from lung cancer he suffocated..'],
#  ['I also downloaded an app "Heart Pal" for tracking the BP.'],
#  ["They're now doing research on therapies for our type of cancer, which is good news."],
#  ['My rads oncologist said no underwire bra for sure because it might irritate my skin.'],
#  ['Definitely not "you have cancer" bald, I did that with the taxol.'],
#  ['You made it thru chemo and you can make it thru radiation, one treatment at a time.'],
#  ['Cancer patients are more likely to survive longer after diagnosis than those who have heart attacks or strokes.'],
#  ['So far all I have done is make myself sore, but I am sure this will go away after a few weeks.'],
#  ['I noticed the dates from the posts so I am not sure I am in the right spot.'],
#  ['So had upper left lobectomy in september 2010.now 6 months later have major pain in left ribcage and arm.'],
#  ['No one except the thoractic surgeon has ever said they have seen anything.'],
#  ['He was having his treatments in three consecutive treatments every 4 weeks.'],
#  ["No Mama G, I don't have that problem."],
#  ['Thanks to everyone your support means so much to me!'],
#  ['I wish I would of left everything alone.'],
#  ['Doctor said I responded very well to chemo.'],
#  ['Second she should be seeing a lung specialist who deals with this type of cancer.'],
#  ['If you dont have  nursing care, and you cannot handle "milking" the drain, enlist one of your family members to do so.'],
#  ["My breast feels different, it itches all the time (the other one doesn't)."],
#  ['Like what she said, drinking a lot of water is the best thing she can do.'],
#  ["I'm in Bloomington, and go for my pap smear Friday, and quite honestly �"],
#  ['I hope we can gain access to The Breast in early 2012 to see and read the full recommendations.'],
#  ["She can't have the Chemo anymore after almost killing her."],
#  ['We are taking a positive attitude and happy that we have at least achieved local control of the tumor.'],
#  ['Feeling OK now but I had my good and bad days.'],
#  ['She helped me find a color similar with frosting, i loved it.'],
#  ["I couldn't sleep through the night and switched from taking my Tamoxifen before bed to taking it in the morning."],
#  ["Every time she goes for scans and it's time for those results, I get scared."],
#  ['That is so hard to do as we all know.'],
#  ["I just don't want to find out if I have cancer again."],
#  ['My friends have already scheduled a "shave the head" party, haha.'],
#  ['They Remove my left lung complete in 2006.'],
#  ['Thank you for thinking of all of us, how beautiful you are!!'],
#  ['I concur with cobra:  each of us handles our treatment differently.'],
#  ['Just breath and know that if this were a cancer, it will have been caught very early and very curable.'],
#  ...]

# %%
# Load the tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# Define a custom dataset
class TextClassificationDataset(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        text = self.data[idx]
        input_ids = torch.tensor(tokenizer.encode(text, add_special_tokens=True)).unsqueeze(0)
        label = torch.tensor(self.labels[idx])
        return input_ids, label

# Create the dataset
dataset = TextClassificationDataset(data, labels)

# Create the data loader
data_loader = DataLoader(dataset, batch_size=1, shuffle=True)

# Load the model
model = GPT2ForSequenceClassification.from_pretrained("gpt2")

# Set the model to train mode
model.train()

# Define the loss function and optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

# Train the model
for epoch in range(10):
    for input_ids, label in data_loader:
        optimizer.zero_grad()
        outputs = model(input_ids, labels=label)
        loss = outputs[0]
        loss.backward()
        optimizer.step()
    print("Epoch:", epoch, "Loss:", loss.item())
# Out:
# Some weights of GPT2ForSequenceClassification were not initialized from the model checkpoint at gpt2 and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch: 0 Loss: 1.4203330278396606
# Epoch: 1 Loss: 0.4850365221500397
# Epoch: 2 Loss: 1.6931101083755493
# Epoch: 3 Loss: 0.3400486409664154
# Epoch: 4 Loss: 0.6747191548347473
# Epoch: 5 Loss: 0.4793832302093506
# Epoch: 6 Loss: 0.5860254168510437
# Epoch: 7 Loss: 0.6583848595619202
# Epoch: 8 Loss: 0.4160294532775879
# Epoch: 9 Loss: 0.44383230805397034

# %%
# Save the fine-tuned model
model.save_pretrained('./gpt-3_model')

# %%
# Prepare the training data
test_seek = pd.read_csv("self_eval_seek_2.csv")
test_seek = test_seek[test_seek["seeking?"].notna()]
test_seek = test_seek.loc[:, ~test_seek.columns.str.contains('^Unnamed')]
test_seek = test_seek.drop_duplicates(subset='seeker_post', keep="last")
test_seek.loc[test_seek["seeking?"]=="Seeking(subtly)", "seeking?"] = int(0)
test_seek.loc[test_seek["seeking?"]=="Not Seeking", "seeking?"] = int(0)
test_seek.loc[test_seek["seeking?"]=="Not Seeking/Maybe", "seeking?"] = int(0)
test_seek.loc[test_seek["seeking?"]=="Seeking(truly)", "seeking?"] = int(1)
test_seek["seeking?"].value_counts()

test_data = []
for i in test_seek["seeker_post"]:
    test_data.append([i])
data
test_labels = test_seek["seeking?"].to_list()

# %%
# Load the model from disk
model = torch.load("model.pt")
model.eval()

# Create the dataset
dataset = TextClassificationDataset(test_data, test_labels)

# Create the data loader
data_loader = DataLoader(dataset, batch_size=1, shuffle=True)

# Evaluate the model on a test dataset
test_loss = 0
test_acc = 0
for input_ids, label in test_loader:
    with torch.no_grad():
        outputs = model(input_ids, labels=label)
        loss = outputs[0]
        logits = outputs[1]
        test_loss += loss.item()
        probs = F.softmax(logits, dim=1)
        pred = probs.argmax(dim=1)
        test_acc += (pred == label).sum().item()

# Calculate the average loss and accuracy
test_loss /= len(test_loader)
test_acc /= len(test_loader) * input_ids.shape[0]

print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)
